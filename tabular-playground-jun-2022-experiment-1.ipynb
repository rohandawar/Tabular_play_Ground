# %% [raw]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# _This notebook is the first expermentation done as a part of **Tabular Playground June 2022**, here we have been given the task to impute the values in the dataset. Lets start by importing the libraries_

# %%
#Importing the Libs

#General
import pandas as pd
import numpy as np

# Time tracking
from tqdm import tqdm

# Path
from pathlib import Path

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Sklearn
from sklearn.impute import SimpleImputer


# Settings
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 300)

# %%
#reading the dataset
df = pd.read_csv('../input/tabular-playground-series-jun-2022/data.csv', index_col='row_id') # setting row_id as index column
df.head()
# Out:
#            F_1_0     F_1_1     F_1_2     F_1_3     F_1_4     F_1_5     F_1_6  \
# row_id
# 0      -0.354591 -0.464038  2.304115  0.734486  1.696395  0.136285 -0.518344
# 1       1.380940 -0.499626 -0.418548  1.911725 -0.826130 -1.715371 -0.577091
# 2       0.256023 -1.059874       NaN  0.345678  1.513814  1.243864 -0.509648
# 3      -0.728420 -2.432399 -2.453602 -0.020509  0.333397  0.086049 -1.787601
# 4       0.590212 -0.066127  0.468009 -1.096038  0.119399 -1.809710  0.466358
#
#            F_1_7     F_1_8     F_1_9    F_1_10    F_1_11    F_1_12    F_1_13  \
# row_id
# 0       0.502640 -1.852504 -0.500665 -1.416075  1.201521  0.551902 -0.759827
# 1      -1.041486  0.596067 -0.363425 -0.853630  0.674525  0.843058 -0.041438
# 2      -0.800481 -0.115945  0.595777 -0.073235 -1.381605 -0.108676  0.703693
# 3       0.667011  0.761564 -2.217847 -0.618973  0.742112  0.494157  0.744673
# 4      -0.053196 -0.580320 -1.143500  1.338692  1.193330  1.038010 -0.763692
#
# ...

# %%
#reading the submission file
submission = pd.read_csv('../input/tabular-playground-series-jun-2022/sample_submission.csv', index_col='row-col') #setting row-col as index
submission.head()
# Out:
#           value
# row-col
# 0-F_1_14    0.0
# 0-F_3_23    0.0
# 1-F_3_24    0.0
# 2-F_1_2     0.0
# 2-F_4_2     0.0

# %% [markdown]
# Now that we have loaded the data, lets check the missing values & data shape for the dataframe

# %%
print('# of rows in the dataframe is: ', df.shape[0])
print('# of columns in the dataframe is: ', df.shape[1])
# Out:
# # of rows in the dataframe is:  1000000
# # of columns in the dataframe is:  80

# %%
#missing data 
df.isnull().sum()
# Out:
# F_1_0     18397
# F_1_1     18216
# F_1_2     18008
# F_1_3     18250
# F_1_4     18322
# F_1_5     18089
# F_1_6     18133
# F_1_7     18128
# F_1_8     18162
# F_1_9     18249
# F_1_10    17961
# F_1_11    18170
# F_1_12    18203
# F_1_13    18398
# F_1_14    18039
# F_2_0         0
# F_2_1         0
# F_2_2         0
# F_2_3         0
# F_2_4         0
# F_2_5         0
# F_2_6         0
# F_2_7         0
# F_2_8         0
# F_2_9         0
# F_2_10        0
# F_2_11        0
# F_2_12        0
# F_2_13        0
# F_2_14        0
# F_2_15        0
# F_2_16        0
# F_2_17        0
# F_2_18        0
# F_2_19        0
# F_2_20        0
# F_2_21        0
# F_2_22        0
# F_2_23        0
# F_2_24        0
# F_3_0     18029
# F_3_1     18345
# F_3_2     18056
# F_3_3     18054
# F_3_4     18373
# F_3_5     18298
# F_3_6     18192
# F_3_7     18013
# F_3_8     18098
# F_3_9     18106
# F_3_10    18200
# F_3_11    18388
# F_3_12    18297
# F_3_13    18060
# F_3_14    18139
# ...

# %% [markdown]
# So, we see that out of the 80 columns, we have missing values in the columns with the following prefix's
#
# - F_1_X
# - F_3_X
# - F_4_X

# %% [markdown]
# As the first strategy, let's try simple imputor from sklearn taking mean as the strategy as "mean", this is also the baseline solution provided with the dataset.

# %%
# Instiate the imputor
imp = SimpleImputer(missing_values=np.nan,
                   strategy='mean')

#fiting the data
data = imp.fit_transform(df)

# Display, just curious :)
data
# Out:
# array([[-3.54591000e-01, -4.64038000e-01,  2.30411500e+00, ...,
#          3.80950500e+00,  1.23648600e+00,  1.18205500e+00],
#        [ 1.38094000e+00, -4.99626000e-01, -4.18548000e-01, ...,
#         -4.21825900e+00, -2.72488300e+00, -6.37750000e-02],
#        [ 2.56023000e-01, -1.05987400e+00,  5.50681434e-04, ...,
#         -2.13174700e+00,  3.66149900e+00, -1.31576000e-01],
#        ...,
#        [ 1.47534000e-01, -7.15276000e-01, -4.65049000e-01, ...,
#         -5.84108000e-01, -1.49209600e+00, -9.97502000e-01],
#        [-1.70988600e+00, -8.13785000e-01, -1.86653600e+00, ...,
#         -1.08555400e+00,  3.12242300e+00,  4.83100000e-03],
#        [-8.06380000e-01, -2.52510000e-02, -8.75477000e-01, ...,
#          2.33413100e+00,  5.42542100e+00, -8.28847000e-01]])

# %% [markdown]
# Now that we have found the missing values, we have to fill them up in the submissions file.

# %%
for i in tqdm(submission.index):
    row  = int(i.split('-')[0])
    col = i.split('-')[1]
    submission.loc[i,'value'] = df.loc[row,col]
    
#save the file
submission.to_csv('submission.csv')
# Out:
# 100%|██████████| 1000000/1000000 [01:25<00:00, 11646.61it/s]
